# %%
paragraph="""The automated systems are constantly automating tasks for the automation engineers. While the researchers were researching, they discovered that many researchable topics had already been researched by previous generations. Happily, the happiness found in organized organizing leads to an organizational triumph that most organizations strive for daily
"""

# %%
import nltk
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['The automated systems are constantly automating tasks for the automation engineers.',
#  'While the researchers were researching, they discovered that many researchable topics had already been researched by previous generations.',
#  'Happily, the happiness found in organized organizing leads to an organizational triumph that most organizations strive for daily']

# %%
## we will findout the pos tag
from nltk.corpus import stopwords

# %% [markdown]
# from
