# %%
words = ["playing", "player", "plays", "played","generously", "generous", "generation","happily", "happiness", "happy"]

# %%
from nltk.stem import PorterStemmer
streming = PorterStemmer()
for word in words:
    print(word+" ------> "+streming.stem(word))
# Out:
# playing ------> play
# player ------> player
# plays ------> play
# played ------> play
# generously ------> gener
# generous ------> gener
# generation ------> gener
# happily ------> happili
# happiness ------> happi
# happy ------> happi

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$',min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %%
from nltk.stem import SnowballStemmer
stemmer=SnowballStemmer('english')

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")

words = ["running", "runs", "ran", "easily", "fairly"]

for word in words:
    print(word + " -------> " + stemmer.stem(word))
# Out:
# running -------> run
# runs -------> run
# ran -------> ran
# easily -------> easili
# fairly -------> fair
