# %%
corpus= """The quick brown fox jumps over the lazy dog.
Sometimes, the simplest moments lead to the most unexpected adventures.
"""

# %%
print(corpus)
# Out:
# The quick brown fox jumps over the lazy dog.
# Sometimes, the simplest moments lead to the most unexpected adventures.

# %%
import nltk

nltk.data.path.append('/Users/arpan/nltk_data')

# %%
from nltk.tokenize import sent_tokenize

corpus = """The quick brown fox jumps over the lazy dog.
Sometimes, the simplest moments lead to the most unexpected adventures."""

print(sent_tokenize(corpus))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[12], line 6
#       1 from nltk.tokenize import sent_tokenize
#       3 corpus = """The quick brown fox jumps over the lazy dog.
#       4 Sometimes, the simplest moments lead to the most unexpected adventures."""
# ----> 6 print(sent_tokenize(corpus))
#
# File ~/Desktop/AI Engineer/myenv/lib/python3.13/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# ...

# %%
import nltk

nltk.data.path
# Out:
# ['/Users/arpan/nltk_data',
#  '/Users/arpan/Desktop/AI Engineer/myenv/nltk_data',
#  '/Users/arpan/Desktop/AI Engineer/myenv/share/nltk_data',
#  '/Users/arpan/Desktop/AI Engineer/myenv/lib/nltk_data',
#  '/usr/share/nltk_data',
#  '/usr/local/share/nltk_data',
#  '/usr/lib/nltk_data',
#  '/usr/local/lib/nltk_data',
#  '/Users/arpan/nltk_data']

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/arpan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

corpus = """The quick brown fox jumps over the lazy dog.
Sometimes, the simplest moments lead to the most unexpected adventures."""

print(sent_tokenize(corpus))
# Out:
# ['The quick brown fox jumps over the lazy dog.', 'Sometimes, the simplest moments lead to the most unexpected adventures.']

# %%
## tokenization
## paragraph --> word
## sentence --> word

from nltk.tokenize import word_tokenize
print(word_tokenize(corpus))
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.', 'Sometimes', ',', 'the', 'simplest', 'moments', 'lead', 'to', 'the', 'most', 'unexpected', 'adventures', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
print(wordpunct_tokenize(corpus))
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.', 'Sometimes', ',', 'the', 'simplest', 'moments', 'lead', 'to', 'the', 'most', 'unexpected', 'adventures', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog.',
#  'Sometimes',
#  ',',
#  'the',
#  'simplest',
#  'moments',
#  'lead',
#  'to',
#  'the',
#  'most',
#  'unexpected',
#  'adventures',
#  '.']
