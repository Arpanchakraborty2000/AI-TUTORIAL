# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/arpan/nltk_data...
# True

# %%
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "runs", "ran", "better"]

for word in words:
    print(word, "→", lemmatizer.lemmatize(word, pos="v"))
# Out:
# running → run
# runs → run
# ran → run
# better → better

# %%
## POS Tagging + Lemmatization

import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize

lemmatizer = WordNetLemmatizer()

# Convert POS tag to WordNet format
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

text = "The boys are running faster than the girls"

tokens = word_tokenize(text)
tagged = pos_tag(tokens)

lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in tagged]

print(lemmatized)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[12], line 26
#      23 text = "The boys are running faster than the girls"
#      25 tokens = word_tokenize(text)
# ---> 26 tagged = pos_tag(tokens)
#      28 lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in tagged]
#      30 print(lemmatized)
#
# File ~/Desktop/AI Engineer/myenv/lib/python3.13/site-packages/nltk/tag/__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)    166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~/Desktop/AI Engineer/myenv/lib/python3.13/site-packages/nltk/tag/__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~/Desktop/AI Engineer/myenv/lib/python3.13/site-packages/nltk/tag/perceptron.py:183, in PerceptronTagger.__init__(self, load, lang, loc)
#     179 self.save_dir = path_join(
#     180     self.TRAINED_TAGGER_PATH, f"{self.TAGGER_NAME}_{self.lang}"
#     181 )
#     182 if load:
# --> 183     self.load_from_json(lang, loc)
#
# File ~/Desktop/AI Engineer/myenv/lib/python3.13/site-packages/nltk/tag/perceptron.py:281, in PerceptronTagger.load_from_json(self, lang, loc)
#     277 def load_from_json(self, lang="eng", loc=None):
#     278     # Automatically find path to the tagger if location is not specified.
#     279     # loc can refer to zip or real FS
#     280     if loc is None:
# --> 281         loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     282     elif isinstance(loc, str):
#     283         # Backward compatible:
#     284         # - absolute paths are explicit filesystem locations
#     285         # - relative strings are treated as NLTK resource names and resolved via find()
#     286         if os.path.isabs(loc):
#
# File ~/Desktop/AI Engineer/myenv/lib/python3.13/site-packages/nltk/data.py:696, in find(resource_name, paths)
#     694 sep = "*" * 70
#     695 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 696 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'averaged_perceptron_tagger_eng' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'taggers/averaged_perceptron_tagger_eng/'
#
#   Searched in:
#     - '/Users/arpan/nltk_data'
#     - '/Users/arpan/Desktop/AI Engineer/myenv/nltk_data'
#     - '/Users/arpan/Desktop/AI Engineer/myenv/share/nltk_data'
#     - '/Users/arpan/Desktop/AI Engineer/myenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /Users/arpan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/arpan/nltk_data...
# True
