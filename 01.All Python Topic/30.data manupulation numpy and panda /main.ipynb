# %%
from operator import index
# !pip install pandas

import pandas as pd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 10.2 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 10.6 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...

# %%
df = pd.read_csv('Data.csv')
## fetch first five row 
df.head(5)
# Out:
#   Synthetic_Data  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             ID        Date     Segment     Region    Product    Channel
# 1              1  2024-01-01    Consumer      North      Omega        Web
# 2              2  2024-01-02  Enterprise       West      Delta    Partner
# 3              3  2024-01-03         SMB       West      Gamma      Store
# 4              4  2024-01-04         SMB      South       Beta        Web
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 50 Unnamed: 51  \
# 0      Units      Price   Discount  Gross_Sales  ...  Feature_33  Feature_34
# 1          7      35.95     0.0778       251.65  ...      0.2445     -0.7512
# 2         11      29.56     0.0301       325.16  ...     -0.6756     -1.8047
# 3         15      34.96     0.1333        524.4  ...      1.3465     -0.3722
# 4         16      27.45     0.0997        439.2  ...     -1.9772      0.3657
#
# ...

# %%
df.tail(5)
# Out:
#     Synthetic_Data  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 296            296  2024-10-22   Consumer       West      Gamma        Web
# 297            297  2024-10-23        SMB      South       Beta     Mobile
# 298            298  2024-10-24   Consumer       West      Gamma      Store
# 299            299  2024-10-25        SMB       East      Omega     Mobile
# 300            300  2024-10-26   Consumer       East      Delta     Mobile
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 50 Unnamed: 51  \
# 296          5      17.23     0.0117      86.15  ...     -1.1593     -0.2564
# 297         10      27.03     0.1469      270.3  ...      -0.974      0.2855
# 298         13       31.7     0.0426      412.1  ...     -1.3334      0.8032
# 299          9      16.64      0.004     149.76  ...     -1.6917     -0.6144
# 300         17      18.28     0.0796     310.76  ...     -0.0549     -1.3918
#
# ...

# %%
df.describe()
## it will find all the statistical data
# Out:
#        Synthetic_Data Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count             301        301        301        301        301        301
# unique            301        301          4          5          6          5
# top                ID       Date   Consumer      North      Omega        Web
# freq                1          1        165         89         65        103
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 50  \
# count         301        301        301        301  ...         301
# unique         21        286        274        300  ...         300
# top            13      34.96     0.0778     149.76  ...     -0.2759
# freq           40          2          2          2  ...           2
#
#        Unnamed: 51 Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55  \
# count          301         301         301         301         301
# unique         299         299         301         299         299
# ...

# %%
df.dtypes
# Out:
# Synthetic_Data    str
# Unnamed: 1        str
# Unnamed: 2        str
# Unnamed: 3        str
# Unnamed: 4        str
# Unnamed: 5        str
# Unnamed: 6        str
# Unnamed: 7        str
# Unnamed: 8        str
# Unnamed: 9        str
# Unnamed: 10       str
# Unnamed: 11       str
# Unnamed: 12       str
# Unnamed: 13       str
# Unnamed: 14       str
# Unnamed: 15       str
# Unnamed: 16       str
# Unnamed: 17       str
# Unnamed: 18       str
# Unnamed: 19       str
# Unnamed: 20       str
# Unnamed: 21       str
# Unnamed: 22       str
# Unnamed: 23       str
# Unnamed: 24       str
# Unnamed: 25       str
# Unnamed: 26       str
# Unnamed: 27       str
# Unnamed: 28       str
# Unnamed: 29       str
# Unnamed: 30       str
# Unnamed: 31       str
# Unnamed: 32       str
# Unnamed: 33       str
# Unnamed: 34       str
# Unnamed: 35       str
# Unnamed: 36       str
# Unnamed: 37       str
# Unnamed: 38       str
# Unnamed: 39       str
# Unnamed: 40       str
# ...

# %%
###Handeling miisssing value 
df.isnull
# Out:
# <bound method DataFrame.isnull of     Synthetic_Data  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0               ID        Date     Segment     Region    Product    Channel
# 1                1  2024-01-01    Consumer      North      Omega        Web
# 2                2  2024-01-02  Enterprise       West      Delta    Partner
# 3                3  2024-01-03         SMB       West      Gamma      Store
# 4                4  2024-01-04         SMB      South       Beta        Web
# ..             ...         ...         ...        ...        ...        ...
# 296            296  2024-10-22    Consumer       West      Gamma        Web
# 297            297  2024-10-23         SMB      South       Beta     Mobile
# 298            298  2024-10-24    Consumer       West      Gamma      Store
# 299            299  2024-10-25         SMB       East      Omega     Mobile
# 300            300  2024-10-26    Consumer       East      Delta     Mobile
#
# ...

# %%
###Handeling miisssing value 
df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
df.isnull().sum()
# Out:
# Synthetic_Data    0
# Unnamed: 1        0
# Unnamed: 2        0
# Unnamed: 3        0
# Unnamed: 4        0
# Unnamed: 5        0
# Unnamed: 6        0
# Unnamed: 7        0
# Unnamed: 8        0
# Unnamed: 9        0
# Unnamed: 10       0
# Unnamed: 11       0
# Unnamed: 12       0
# Unnamed: 13       0
# Unnamed: 14       0
# Unnamed: 15       0
# Unnamed: 16       0
# Unnamed: 17       0
# Unnamed: 18       0
# Unnamed: 19       0
# Unnamed: 20       0
# Unnamed: 21       0
# Unnamed: 22       0
# Unnamed: 23       0
# Unnamed: 24       0
# Unnamed: 25       0
# Unnamed: 26       0
# Unnamed: 27       0
# Unnamed: 28       0
# Unnamed: 29       0
# Unnamed: 30       0
# Unnamed: 31       0
# Unnamed: 32       0
# Unnamed: 33       0
# Unnamed: 34       0
# Unnamed: 35       0
# Unnamed: 36       0
# Unnamed: 37       0
# Unnamed: 38       0
# Unnamed: 39       0
# Unnamed: 40       0
# Unnamed: 41       0
# Unnamed: 42       0
# Unnamed: 43       0
# Unnamed: 44       0
# ...

# %%
df.head(10)
# Out:
#   Synthetic_Data  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             ID        Date     Segment     Region    Product    Channel
# 1              1  2024-01-01    Consumer      North      Omega        Web
# 2              2  2024-01-02  Enterprise       West      Delta    Partner
# 3              3  2024-01-03         SMB       West      Gamma      Store
# 4              4  2024-01-04         SMB      South       Beta        Web
# 5              5  2024-01-05    Consumer       East       Beta      Store
# 6              6  2024-01-06    Consumer       East      Gamma     Mobile
# 7              7  2024-01-07    Consumer       East      Gamma      Store
# 8              8  2024-01-08  Enterprise       West      Omega      Store
# 9              9  2024-01-09         SMB       West      Omega        Web
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 50 Unnamed: 51  \
# ...

# %%
### Renaming the column
df.rename(columns={'Unnamed: 1':'fst_column'})
# Out:
#     Synthetic_Data  fst_column  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0               ID        Date     Segment     Region    Product    Channel
# 1                1  2024-01-01    Consumer      North      Omega        Web
# 2                2  2024-01-02  Enterprise       West      Delta    Partner
# 3                3  2024-01-03         SMB       West      Gamma      Store
# 4                4  2024-01-04         SMB      South       Beta        Web
# ..             ...         ...         ...        ...        ...        ...
# 296            296  2024-10-22    Consumer       West      Gamma        Web
# 297            297  2024-10-23         SMB      South       Beta     Mobile
# 298            298  2024-10-24    Consumer       West      Gamma      Store
# 299            299  2024-10-25         SMB       East      Omega     Mobile
# 300            300  2024-10-26    Consumer       East      Delta     Mobile
#
# ...
