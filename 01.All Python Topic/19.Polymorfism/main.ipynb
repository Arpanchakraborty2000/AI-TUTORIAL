# %%
class Animal:
    def speak(self):
        return "Sound of a animal ..."
    
## derive class 1

class Dog(Animal):
    def speak(self):
        return "Woof ..."

## derive class 2

class Cat(Animal):
    def speak(self):
        return "Meao ..."
    
    
### Function that demostrate polymorphism

def animal_speak(animal):
    print(animal.speak())


cat = Cat()
dog = Dog()

print(cat.speak())
print(dog.speak())
animal_speak(dog)

# %%
## polymorphism with funtion and method 

## Base class

class Shape:
    def shape(self):
        return " The area of the figure ..."
    
## Derive class -1

class Rectangel(Shape):
    def __init__(self,weith,height):
        self.weith =weith
        self.height=height
        
    def area(self):
        return self.weith * self.height 
       
## Derive class - 2

class Circle(Shape):
    def __init__(self,redius):
        self.redius=redius
        
    def area(self):
        return 3.14*self.redius*self.redius
    
    
## demostrate polymorphism 

def print_area(shape):
        print(f"The area is {shape.area()}")
        
        
rectangel =Rectangel(4,3)
circle = Circle(10)

print_area(rectangel)
print_area(circle)
# Out:
# The area is 12
# The area is 314.0

# %%
## Polymorphism with Abstract Class Example


from abc import ABC, abstractmethod

# Abstract Base Class
class Shape(ABC):
    
    @abstractmethod
    def area(self):
        pass  # Abstract method: must be implemented by subclasses

# Derived class - Rectangle
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
        
    def area(self):
        return self.width * self.height

# Derived class - Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
        
    def area(self):
        return 3.14 * self.radius * self.radius

# Polymorphic function
def print_area(shape: Shape):
    print(f"The area is {shape.area()}")  # Calls the correct method for each object

# Create objects
rectangle = Rectangle(4, 3)
circle = Circle(10)

# Demonstrate polymorphism
print_area(rectangle)  # The area is 12
print_area(circle)     # The area is 314.0
